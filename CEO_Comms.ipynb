# %% [markdown]
# # **Notebook for Conducitng the analysis of the AlixPartners Analysis for the CEO Comms Reports**
#
# This report is to answer some basic quesitons about the Soical Media presence of the AlixPartners CEO.
#
# #### Social Media Channels
# - LinkedIn
# - Twitter
# - Facebook
#
# #### Data Source
# - Hootsuite *(data will be pulled CSV)*
#
# #### CEO Comms Digital Goals
# - **Grow Simon’s digital influence:**
#  - Increase **Simon’s LinkedIn followership** *(monthly follower growth rate)*
#  - Increase **Simon’s LinkedIn reach** *(impressions)*
#  - Increase **Simon’s LinkedIn engagement** *(engagement rate)*
#
#  #### Analysis Project Goals:
# - Analyze data from the first half of 2021 to inform and improve our CEO Comms social and web strategy.
# - Provide recommendations to help improve our strategy for growing Simon’s digital influence
#
# *Data set: https://alixpartners.box.com/s/ef3zwzidulcb7a5i2inahgxqfmjl2skm (to be updated)*
#
# ## Corporate social accounts analysis objectives (to be added by Leslie)
# Determine whether:
# *NEED INFO*
#
# ## Simon’s LinkedIn account analysis objectives (to be added by Leslie)
# **Determine whether:**
# - [there is a correlation between the number of Simon’s posts per period and followership   *(H1)*](#H1)
# - [there is a correlation between the frequency of Simon’s posts and followership *(H2)*](#H2)
# - [there is a correlation between the types of posts and followership. Post types: status update (text only), image post, video post *(H3)*](#H3)
# - [there is a correlation between the post times of day and followership *(H4)*](#H4)
# - [there is a correlation between the post days of week of day and followership *(H5)*](#H5)
# - [there is a correlation between post comments and followership *(H6)*](#H6)
# - [there is a correlation between the post times of day and followership *(H7)*](#H7)
# - [there is a correlation between the post days of week of day and followership *(H8)*](#H8)
# - [there is a correlation between LinkedIn pulse article frequency and followership *(H9)*](#H9)
# - [there are certain topics that perform better in terms of impressions *(H10)*](#H10)
# - [there are certain topics that perform better in terms of engagement rate *(H11)*](#H11)
# - [there is a correlation between the frequency of Simon’s posts and engagement rate *(H12)*](#H12)
# - [there is a correlation between the types of posts and engagement rate. Post types: status update (text only), image post, video post *(H13)*](#H13)
# - [there is a correlation between the post times of day and engagement rate *(H14)*](#H14)
# - [there is a correlation between the post days of week of day and engagement rate *(H15)*](#H15)

# %% [markdown]
# ### LinkedIn Analysis

# %% [markdown]
# *Data Varaibles Avaiable*
#
#
# |Varaible | Definition |
# |:--|----|
# | Source Date |   |
# | Username |   |
# | Source URL |   |
# | User Photo |   |
# | Text |   |
# | Tags |   |
# | Campaign |   |
# | Link(s) |   |
# | Expanded Link(s) |   |
# | Image |   |
# | ROI |   |
# | Post clicks |   |
# | Post comments |   |
# | Post impressions |   |
# | Post reactions |   |
# | Total ROI |   |
# | Post shares |   |
# | Post time watched |   |
# | Post time watched for video views |   |
# | Post video views |   |
# | Post video viewers |   |
# | Total engagements |   |
# | FAS Anti Corruption Adwords |   |
# | Multi-Page Sessions |   |
# | Downloaded PDF |   |
# | Completed job application |   |
# | Main Contact Page - Thank You |   |
# | Join Mailing List |   |
# | Email Click |   |
# | Phone Calls from Mobile |   |
# | Get Directions |   |
# | Website Pageviews |   |
# | Website Visits |   |
# | Transactions |   |
# | Goal Completions All |   |
# | Goal Values |   |
# | Website Sessions |   |
# | Ecommerce Revenue |   |

# %% [markdown]
# #### *These are the libraries needed for the report pulling*

# %%
### Libraries

library(tidyverse)
library(dplyr)
library(lubridate)
library(stringer)

# %% [markdown]
# #### Cleaning the data

# %%
# Importing the data CSV

linkindf <- read.csv (choose.files(), StringAsFactors = "FALSE")

str(linkindf)

# Spliting up date and time
## Need to figure out if date format will include the time.  If not need to split the time from the cell
linkindf$Source.Date <- ymdhm(linkindf$Source.Date)

# Adding in the classification of Post Type
linkindf <- linkindf %>%
  mutate(Post.Type = )  #I need to get clearificaiton on how to figure out the post type

str(linkindf)   #review the data types to ensure correct

# %% [markdown]
# #### Setting up the Correaltion test

# %% [markdown]
# ##### there is a correlation between the number of Simon’s posts per period and followership  <a id="H1"></a>

# %%
# Need to figure our what is defined as Followership?

h1 <- cor.test( x= length(linkindf$Source.Date), y= , method=c("pearson", "kendall", "spearman"))
View (h1)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the frequency of Simon’s posts and followership
# <a id='H2'></a>

# %%
h2 <- cor.test( x= length(linkindf$Source.Date), y= , method=c("pearson", "kendall", "spearman"))
View (h2)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the types of posts and followership. Post types: status update (text only), image post, video post
#
# <a id='H3'></a>

# %%
h3 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h3)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the post times of day and followership
#
#
# <a id='H4'></a>

# %%
h4 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h4)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the post days of week of day and followership
#
# <a id='H5'></a>

# %%
h5 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h5)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between post comments and followership
#
#
# <a id='H6'></a>

# %%
h6 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h6)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the post times of day and followership
#
# <a id='H7'></a>

# %%
h7 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h7)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the post days of week of day and followership
#
# <a id='H8'></a>

# %%
h8 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h8)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between LinkedIn pulse article frequency and followership
#
#
# <a id='H9'></a>

# %%
h9 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h9)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there are certain topics that perform better in terms of impressions
#
# <a id='H10'></a>

# %%
h10 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h10)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there are certain topics that perform better in terms of engagement rate
#
#
# <a id='H11'></a>

# %%
h11 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h11)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the frequency of Simon’s posts and engagement rate
#
#
# <a id='H12'></a>

# %%
h12 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h12)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the types of posts and engagement rate. Post types: status update (text only), image post, video post
#
#
# <a id='H13'></a>

# %%
h13 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h13)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the post times of day and engagement rate
#
#
# <a id='H14'></a>

# %%
h14 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h14)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line

# %% [markdown]
# ##### there is a correlation between the post days of week of day and engagement rate
#
#
# <a id='H15'></a>

# %%
h15 <- cor.test( x= length(), y= , method=c("pearson", "kendall", "spearman"))
View (h15)


# Plotting the Chart
##  *Need The barnding code set up
ggplot(linkindf, aes(x = , y =  )) +
  geom_point () + # Might need to use scatter
  geom_smooth(method=lm, se=FALSE)  # This adds a linear line
